# %%
import os.path
###### Mount Point 1 through Oauth security.
storageAccount = "gen10datafund2202"
storageContainer = "guinea-pig-capstone"
clientSecret = "B4g8Q~1VyZJa5WszLHwdEQNq4YIaHmT4DevRBcwI"
clientid = "2ca50102-5717-4373-b796-39d06568588d"
mount_point = "/mnt/guinea-pig-capstone/origin"


configs = {"fs.azure.account.auth.type": "OAuth",
       "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
       "fs.azure.account.oauth2.client.id": clientid,
       "fs.azure.account.oauth2.client.secret": clientSecret,
       "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/d46b54b2-a652-420b-aa5a-2ef7f8fc706e/oauth2/token",
       "fs.azure.createRemoteFileSystemDuringInitialization": "true"}

try: 
    dbutils.fs.unmount(mount_point)
except:
    pass

dbutils.fs.mount(
source = "abfss://"+storageContainer+"@"+storageAccount+".dfs.core.windows.net/",
mount_point = mount_point,
extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/guinea-pig-capstone/origin has been unmounted.
# Out[32]: True</div>

# %%
ndf_1 = spark.read.options(header = True).csv('dbfs:/mnt/guinea-pig-capstone/origin/origin/CleanedUnemployement.csv')
display(ndf_1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
ndf_2 = spark.read.options(header = True).csv('dbfs:/mnt/guinea-pig-capstone/origin/origin/census.csv')
ndf_3 = spark.read.options(header = True).csv('dbfs:/mnt/guinea-pig-capstone/origin/origin/full-disaster-loan.csv')
ndf_4 = spark.read.options(header = True).csv('/mnt/guinea-pig-capstone/origin/origin/SP500TheFinalFinal.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Census_Unemployment_df = ndf_1.join(ndf_2,(ndf_1['State'] == ndf_2['State'])&(ndf_1['County'] == ndf_2['County'])&(ndf_1['Year'] == ndf_2['Year']),how="inner").select(
        ndf_1["*"],
        *[ndf_2[c] for c in ndf_2.columns if c not in ["State","County","Year"]]
    )
display(Census_Unemployment_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
SP_Unemp_Census_df = Census_Unemployment_df.join(ndf_4, Census_Unemployment_df['Year'] == ndf_4['Year_SP'],how="inner").select(
        Census_Unemployment_df["*"],
        *[ndf_4[c] for c in ndf_4.columns if c not in ["Year_SP"]]
    )


#DL_Unemp_Census_df = Census_Unemployment_df.join(ndf_3,(Census_Unemployment_df['State'] == ndf_3['State Name'])&(Census_Unemployment_df['County'] == ndf_3['County Name'])&(Census_Unemployment_df['Year'] == ndf_3['Year']),how="inner").select(
#        Census_Unemployment_df["*"],
#        *[ndf_3[c] for c in ndf_3.columns if c not in ["State Name", "County Name", "Year"]]
#    )

display(SP_Unemp_Census_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
Guinea_Pig_Not_Normal = SP_Unemp_Census_df.join(ndf_3,(SP_Unemp_Census_df['State'] == ndf_3['State Name'])&(SP_Unemp_Census_df['County'] == ndf_3['County Name'])&(SP_Unemp_Census_df['Year'] == ndf_3['Year']),how="left").select(
        SP_Unemp_Census_df["*"],
        *[ndf_3[c] for c in ndf_3.columns if c not in ["State Name", "County Name", "Year"]]
)
display(Guinea_Pig_Not_Normal)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
Guinea_Pig_Not_Normal = Guinea_Pig_Not_Normal.na.fill(value='0')
Guinea_Pig_Not_Normal.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: 5465</div>

# %%
# Define Error Callbacks
def error_cb(err):
    """ The error callback is used for generic client errors. These
        errors are generally to be considered informational as the client will
        automatically try to recover from all errors, and no extra action
        is typically required by the application.
        For this example however, we terminate the application if the client
        is unable to connect to any broker (_ALL_BROKERS_DOWN) and on
        authentication errors (_AUTHENTICATION). """

    print("Client error: {}".format(err))
    if err.code() == KafkaError._ALL_BROKERS_DOWN or \
       err.code() == KafkaError._AUTHENTICATION:
        # Any exception raised from this callback will be re-raised from the
        # triggering flush() or poll() call.
        raise KafkaException(err)


def acked(err, msg):
    """ 
        Error callback is used for generic issues for producer errors. 
        
        Parameters:
            err (err): Error flag.
            msg (str): Error message that was part of the callback.
    """
    if err is not None:
        print("Failed to deliver message: %s: %s" % (str(msg), str(err)))
    else:
        print("Message produced: %s" % (str(msg)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Connection String
from confluent_kafka import Consumer
from time import sleep
import uuid
from confluent_kafka import Producer, KafkaError, KafkaException
import json
from confluent_kafka.admin import AdminClient, NewTopic

########### CHANGE CONFLUENT TOPIC NAME TO YOUR TOPIC NAME THAT YOU CREATE ########################

#KAFKA variables, Move to the OS variables or configuration
# This will work in local Jupiter Notebook, but in a databrick, hiding config.py is tougher. 
confluentClusterName = "stage3talent"
confluentBootstrapServers = "pkc-ldvmy.centralus.azure.confluent.cloud:9092"
confluentTopicName = "guinea-pig-capstone-prod"                                                                                         #Change for final
schemaRegistryUrl = "https://psrc-gq7pv.westus2.azure.confluent.cloud"
confluentApiKey = "YHMHG7E54LJA55XZ"
confluentSecret = "/XYn+w3gHGMqpe9l0TWvA9FznMYNln2STI+dytyPqtZ9QktH0TbGXUqepEsJ/nR0"
confluentRegistryApiKey = "YHMHG7E54LJA55XZ"
confluentRegistrySecret = "/XYn+w3gHGMqpe9l0TWvA9FznMYNln2STI+dytyPqtZ9QktH0TbGXUqepEsJ/nR0"


# Kafka Admin Setup
admin_client = AdminClient({
    'bootstrap.servers': confluentBootstrapServers,
    'sasl.mechanism': 'PLAIN',
    'security.protocol': 'SASL_SSL',
    'sasl.username': confluentApiKey,
    'sasl.password': confluentSecret,
    'group.id': str(uuid.uuid1()),  # this will create a new consumer group on each invocation.
    'auto.offset.reset': 'earliest',
    'error_cb': error_cb,
})
#Kakfa Producer Setup.
p = Producer({
    'bootstrap.servers': confluentBootstrapServers,
    'sasl.mechanism': 'PLAIN',
    'security.protocol': 'SASL_SSL',
    'sasl.username': confluentApiKey,
    'sasl.password': confluentSecret,
    'group.id': str(1),  # this will create a new consumer group on each invocation.
    'auto.offset.reset': 'earliest',
    'error_cb': error_cb,
})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Delete Topic (if it exists)
try:
    topics =['guinea-pig-capstone-prod']
    fs = admin_client.delete_topics(topics, request_timeout=30)

    for topic, f in fs.items():
        try:
            f.result()  # The result itself is None
            print("Topic {} deleted".format(topic))
        except Exception as e:
            print("Failed to delete topic {}: {}".format(topic, e))
except Exception as e:
    print(e)
sleep(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Topic guinea-pig-capstone-prod deleted
# </div>

# %%
# Simple Topic Setup
topic_list = []
topic_list.append(NewTopic("guinea-pig-capstone-prod", 1, 3))         #change for final
futures = admin_client.create_topics(topic_list)

try:
    record_metadata = []
    for k, future in futures.items():
        # f = i.get(timeout=10)
        print(f"type(k): {type(k)}")
        print(f"type(v): {type(future)}")
        print(future.result())

except KafkaError:
    # Decide what to do if produce request failed...
    print(traceback.format_exc())
    result = 'Fail'
finally:
    print("finally")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">type(k): &lt;class &#39;str&#39;&gt;
# type(v): &lt;class &#39;concurrent.futures._base.Future&#39;&gt;
# None
# finally
# </div>

# %%
results = Guinea_Pig_Not_Normal.toJSON().map(lambda j: json.loads(j)).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# This code will take about 90 minutes to run.
# You are sending 1000 messages to Kafka's servers, with a time delay of 5 seconds between each message.
# Simple Producer with JSON message. 

i = 0

while(True):
    
    if i % 200 == 0:
        print(f'Messages Sent: {i}')  # This does nothing it just tells you how many messages you've sent and how many are left
        
    p.produce(confluentTopicName,json.dumps(results[i]))

    p.flush()
    sleep(2) # In the interest of time you can comment this time delay out
    i = i + 1
    
    if i > 5464:
        break
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Messages Sent: 0
# Messages Sent: 200
# Messages Sent: 400
# Messages Sent: 600
# Messages Sent: 800
# Messages Sent: 1000
# Messages Sent: 1200
# Messages Sent: 1400
# Messages Sent: 1600
# Messages Sent: 1800
# Messages Sent: 2000
# Messages Sent: 2200
# Messages Sent: 2400
# Messages Sent: 2600
# Messages Sent: 2800
# Messages Sent: 3000
# Messages Sent: 3200
# Messages Sent: 3400
# Messages Sent: 3600
# Messages Sent: 3800
# Messages Sent: 4000
# Messages Sent: 4200
# Messages Sent: 4400
# Messages Sent: 4600
# Messages Sent: 4800
# Messages Sent: 5000
# Messages Sent: 5200
# Messages Sent: 5400
# </div>
