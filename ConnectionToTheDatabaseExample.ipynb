# %%
import os
import psycopg2 as ps
import pandas as pd

# %%
import pyodbc
server = 'gen10-data-fundamentals-22-02-sql-server.database.windows.net'
database = 'guinea-pigs-database'
username = 'gPigs'
password = 'GuineaPigs!'
driver='{SQL Server}'

cnxn = pyodbc.connect('DRIVER='+driver+';SERVER='+server+';PORT=1433;DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()
cursor.execute("SELECT * FROM DL")
rows = cursor.fetchall()
c = [column[0] for column in cursor.description]
ndf_DL = pd.DataFrame([tuple(t) for t in rows], columns = c) 
ndf_DL
# Out:
#      SBA Physical Declaration Number SBA EIDL Declaration Number  \
# 0                              14021                     14022.0
# 1                              11430                     11431.0
# 2                              14334                     14335.0
# 3                              11430                     11431.0
# 4                              14021                     14022.0
# ...                              ...                         ...
# 1995                           11430                     11431.0
# 1996                           11430                     11431.0
# 1997                           11430                     11431.0
# 1998                           11430                     11431.0
# 1999                           11430                     11431.0
#
#      SBA Disaster Number Damaged Property City Name Damaged Property Zip Code  \
# 0               CA-00221                  ESCONDIDO                   92029.0
# 1               TX-00308                   SAN LEON                   77539.0
# 2               TX-00447                    HOUSTON                     77035
# 3               TX-00308                   SAN LEON                   77539.0
# 4               CA-00221                 SAN MARCOS                   92078.0
# ...                  ...                        ...                       ...
# 1995            TX-00308                SABINE PASS                   77655.0
# 1996            TX-00308                      SACUL                   75788.0
# 1997            TX-00308                   SAN LEON                   77058.0
# 1998            TX-00308                   SAN LEON                   77518.0
# 1999            TX-00308                   SAN LEON                   77531.0
#
#      Damaged Property County/Parish Name Total Verified Loss  \
# 0                              SAN DIEGO              9470.0
# 1                              GALVESTON          19503005.0
# 2                                 HARRIS            356965.0
# 3                                 HARRIS              2500.0
# 4                              SAN DIEGO             51474.0
# ...                                  ...                 ...
# 1995                           JEFFERSON           1134153.0
# 1996                         NACOGDOCHES              4546.0
# 1997                           GALVESTON            114700.0
# 1998                           GALVESTON             47618.0
# 1999                           GALVESTON             76767.0
#
#      Verified Loss Real Estate Verified Loss Content  \
# 0                          0.0                9470.0
# 1                   14532827.0             4970178.0
# 2                     350090.0                6875.0
# 3                          0.0                2500.0
# 4                      51474.0                   0.0
# ...                        ...                   ...
# 1995                 1004462.0              129691.0
# 1996                    3146.0                1400.0
# 1997                       0.0              114700.0
# 1998                   43868.0                3750.0
# 1999                   76767.0                   0.0
#
#      Total Approved Loan Amount Approved Amount Real Estate  \
# 0                        9500.0                         0.0
# 1                     3420800.0                   2344400.0
# 2                      357000.0                    350100.0
# 3                        3900.0                         0.0
# 4                           0.0                         0.0
# ...                         ...                         ...
# 1995                   442900.0                    437400.0
# 1996                        0.0                         0.0
# 1997                    54300.0                         0.0
# 1998                        0.0                         0.0
# 1999                        0.0                         0.0
#
#      Approved Amount Content Approved Amount EIDL  Year       State
# 0                     9500.0                  0.0  2014  California
# 1                   751200.0             325200.0  2008       Texas
# 2                     6900.0                  0.0  2015       Texas
# 3                     2500.0               1400.0  2008       Texas
# 4                        0.0                  0.0  2014  California
# ...                      ...                  ...   ...         ...
# 1995                  3900.0               1600.0  2008       Texas
# 1996                     0.0                  0.0  2008       Texas
# 1997                 39700.0              14600.0  2008       Texas
# 1998                     0.0                  0.0  2008       Texas
# 1999                     0.0                  0.0  2008       Texas
#
# [2000 rows x 15 columns]
