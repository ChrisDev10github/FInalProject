# %%
import os
import pandas as pd
import datetime

# %%
import pyodbc
server = 'gen10-data-fundamentals-22-02-sql-server.database.windows.net'
database = 'guinea-pigs-database'
username = 'gPigs'
password = 'GuineaPigs!'
driver='{SQL Server}'

# %%
cnxn = pyodbc.connect('DRIVER='+driver+';SERVER='+server+';PORT=1433;DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()
cursor.execute("SELECT * FROM DL")
rows = cursor.fetchall()
c = [column[0] for column in cursor.description]
ndf_DL = pd.DataFrame([tuple(t) for t in rows], columns = c) 
ndf_DL
# Out:
#      SBA Physical Declaration Number SBA EIDL Declaration Number  \
# 0                              14173                     14174.0
# 1                              14173                     14174.0
# 2                              14330                     14331.0
# 3                              14330                     14331.0
# 4                              11055                     11056.0
# ...                              ...                         ...
# 8390                           12909                     12910.0
# 8391                           12909                     12910.0
# 8392                           12909                     12910.0
# 8393                           12909                     12910.0
# 8394                           12909                     12910.0
#
#      SBA Disaster Number Damaged Property Zip Code Verified Loss Content  \
# 0               CA-00222                     94589                   0.0
# ...

# %%
cnxn = pyodbc.connect('DRIVER='+driver+';SERVER='+server+';PORT=1433;DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()
cursor.execute("SELECT * FROM SP500")
rows = cursor.fetchall()
c = [column[0] for column in cursor.description]
ndf_SP = pd.DataFrame([tuple(t) for t in rows], columns = c) 

ndf_SP
# Out:
#        Timestamp Year_SP        Market Value
# 0  1652733588578    2011             1277.77
# 1  1652733588576    2010             1135.68
# 2  1652733588558    2008             1292.78
# 3  1652733588592    2015             2076.78
# 4  1652733588589    2014            1933.875
# 5  1652733588581    2012  1382.9099999999999
# 6  1652733588585    2013             1646.49
# 7  1652733588572    2009   935.9449999999999

# %%
cnxn = pyodbc.connect('DRIVER='+driver+';SERVER='+server+';PORT=1433;DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()
cursor.execute("SELECT * FROM Unemployment")
rows = cursor.fetchall()
c = [column[0] for column in cursor.description]
ndf_U = pd.DataFrame([tuple(t) for t in rows], columns = c) 
ndf_U
# Out:
#        Year     State Unemployement     County
# 0      2015      IOWA           2.9      BOONE
# 1      2012    KANSAS           3.4      MEADE
# 2      2015      IOWA           3.4     BREMER
# 3      2012    KANSAS           6.3      MIAMI
# 4      2013  ARKANSAS           7.7    GARLAND
# ...     ...       ...           ...        ...
# 21714  2010  COLORADO           6.3      LOGAN
# 21715  2010  COLORADO          11.0       MESA
# 21716  2010  COLORADO           7.0    MINERAL
# 21717  2010  COLORADO           9.9     MOFFAT
# 21718  2010  COLORADO           9.1  MONTEZUMA
#
# [21719 rows x 4 columns]
